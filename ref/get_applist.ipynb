# %%
# -*- coding:utf-8 -*-

import pandas as pd

dataset = "..\dataset\original_dataset\steam_reviews.csv"
pd.set_option("display.max_rows", 350)

# app_id는 해당 게임의 스팀 구매 페이지 url에 활용
# https://store.steampowered.com/app/{app_id}
df = pd.read_csv(dataset, encoding="utf-8", usecols=["app_id", "app_name"])

# jupyter notebook
display(df.drop_duplicates(["app_id"], ignore_index = True))

# python idle
# print(df.drop_duplicates(["app_id"], ignore_index = True))
# Out:
#       app_id                                       app_name
# 0     292030                       The Witcher 3: Wild Hunt
# 1         70                                      Half-Life
# 2        240                         Counter-Strike: Source
# 3        420                       Half-Life 2: Episode Two
# 4        620                                       Portal 2
# 5       2870                                      X Rebirth
# 6       4000                                    Garry's Mod
# 7       8930                     Sid Meier's Civilization V
# 8     381210                               Dead by Daylight
# 9     289070                    Sid Meier's Civilization VI
# 10    264710                                     Subnautica
# 11    477160                               Human: Fall Flat
# 12    620980                                     Beat Saber
# 13    541210                                    Cold Waters
# 14    242920                                       Banished
# ...
