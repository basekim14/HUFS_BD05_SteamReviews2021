# %%
import pandas as pd
import numpy as np
from numpy.random import randint
from datetime import datetime
import gc
import os
import re
from collections import Counter
import warnings
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
matplotlib.use("TkAgg")
# %matplotlib inline

# %%
target_lang_list = ["koreana", "japanese", "tchinese", "schinese", "thai", "turkish",
                    "english", "french", "german", "italian", "czech", "norwegian", "swedish", "polish",
                    "portuguese", "spanish", "russian"]

# 각 언어별 처리에 필요한 값들을 데이터프레임 형식으로 작성
lang_data_dict = {
    # 언어 코드
    "code" : {
        "schinese": "zh-cn",
        "english": "en",
        "turkish": "tr",
        "spanish": "es",
        "russian": "ru",
        "koreana": "ko",
        "latam": "la",
        "brazilian": "pt",
        "portuguese": "pt",
        "vietnamese": "vi",
        "polish": "pl",
        "french": "fr",
        "german": "de",
        "hungarian": "hu",
        "ukrainian": "uk",
        "tchinese": "zh-tw",
        "bulgarian": "bg",
        "czech": "cs",
        "italian": "it",
        "thai": "th",
        "greek": "el",
        "dutch": "nl",
        "finnish": "fi",
        "romanian": "ro",
        "japanese": "ja",
        "swedish": "sv",
        "danish": "da",
        "norwegian": "no"
    },
    # 언어 별 폰트
    "font_path" : {
        "schinese": "./font/NotoSansSC-Bold.otf",
        "english": "./font/NotoSans-Bold.ttf",
        "turkish": "./font/NotoSans-Bold.ttf",
        "spanish": "./font/NotoSans-Bold.ttf",
        "russian": "./font/NotoSans-Bold.ttf",
        "koreana": "./font/NotoSansKR-Bold.otf",
        "latam": "./font/NotoSans-Bold.ttf",
        "brazilian": "./font/NotoSans-Bold.ttf",
        "portuguese": "./font/NotoSans-Bold.ttf",
        "vietnamese": "./font/NotoSans-Bold.ttf",
        "polish": "./font/NotoSans-Bold.ttf",
        "french": "./font/NotoSans-Bold.ttf",
        "german": "./font/NotoSans-Bold.ttf",
        "hungarian": "./font/NotoSans-Bold.ttf",
        "ukrainian": "./font/NotoSans-Bold.ttf",
        "tchinese": "./font/NotoSansTC-Bold.otf",
        "bulgarian": "./font/NotoSans-Bold.ttf",
        "czech": "./font/NotoSans-Bold.ttf",
        "italian": "font/NotoSans-Bold.ttf",
        "thai": "./font/Itim-Regular.ttf",
        "greek": "./font/NotoSans-Bold.ttf",
        "dutch": "./font/NotoSans-Bold.ttf",
        "finnish": "./font/NotoSans-Bold.ttf",
        "romanian": "./font/NotoSans-Bold.ttf",
        "japanese": "./font/NotoSansJP-Bold.otf",
        "swedish": "./font/NotoSans-Bold.ttf",
        "danish": "./font/NotoSans-Bold.ttf",
        "norwegian": "./font/NotoSans-Bold.ttf"
    },
    # 유니코드를 활용한 정규식 패턴
    "unicode_pattern": {
        "schinese": r"",
        "english": r"[^A-Za-z' ]+", # 띄어쓰기 중요, 다른 언어도 공백 유지 추가
        "turkish": r"",
        "spanish": r"[^\u0041-\u005A\u0061-\u007A\u00C1\u00C9\u00CD\u00D1\u00D3\u00DA\u00D1\u00E1\u00E9\u00ED\u00F1\u00F3\u00FA]+",
        "russian": r"",
        "koreana": r"[^\uAC00-\uD7AF\u1100-\u11FF]+",
        "latam": r"",
        "brazilian": r"",
        "portuguese": r"[^\u0041-\u005A\u0061-\u007A\u00C0-\u00C3\\u00C7-\u00C9\u00CC\u00CD\u00D2-\u00D5\u00D9\u00DA\u00E0-\u00E3\u00E7-\u00EA\u00EC\u00ED\u00F2-\u00F5\u00F9\u00FA]+",
        "vietnamese": r"",
        "polish": r"",
        "french": r"[^\u0041-\u005A\u0061-\u007A\]+",
        "german": r"[^A-Za-z\u00C4\u00D6\u00DC\u00DF\u00E4\u00F6\u00FC]+",
        "hungarian": r"",
        "ukrainian": r"",
        "tchinese": r"",
        "bulgarian": r"",
        "czech": r"",
        "italian": r"[^\u0041-\u005A\u0061-\u007A\u00C0\u00C1\u00C8\u00C0\u00CC\u00CD\u00D2\u00D3\u00D9\u00DA\u00E0\u00E1\u00E8\u00E9\u00EC\u00ED\u00F2\u00F3\u00F9\u00FA]",
        "thai": r"[^\u0E00-\u0E7F]+",
        "greek": r"",
        "dutch": r"",
        "finnish": r"",
        "romanian": r"",
        "japanese": r"",
        "swedish": r"",
        "danish": r"",
        "norwegian": r""
    }
}

# 원하는 값을 닷 연산자로 직관적으로 접근하기 위한 데이터프레임 생성
lang_data = pd.DataFrame([], columns=lang_data_dict.keys(), index=target_lang_list)

for lang in lang_data.index:
    lang_data.loc[lang] = [lang_data_dict[column][lang] for column in lang_data.columns]

display(lang_data)
# Out:
#              code                   font_path  \
# koreana        ko  ./font/NotoSansKR-Bold.otf
# japanese       ja  ./font/NotoSansJP-Bold.otf
# tchinese    zh-tw  ./font/NotoSansTC-Bold.otf
# schinese    zh-cn  ./font/NotoSansSC-Bold.otf
# thai           th     ./font/Itim-Regular.ttf
# turkish        tr    ./font/NotoSans-Bold.ttf
# english        en    ./font/NotoSans-Bold.ttf
# french         fr    ./font/NotoSans-Bold.ttf
# german         de    ./font/NotoSans-Bold.ttf
# italian        it      font/NotoSans-Bold.ttf
# czech          cs    ./font/NotoSans-Bold.ttf
# norwegian      no    ./font/NotoSans-Bold.ttf
# swedish        sv    ./font/NotoSans-Bold.ttf
# polish         pl    ./font/NotoSans-Bold.ttf
# portuguese     pt    ./font/NotoSans-Bold.ttf
# spanish        es    ./font/NotoSans-Bold.ttf
# russian        ru    ./font/NotoSans-Bold.ttf
#
#                                               unicode_pattern
# koreana                        [^\uAC00-\uD7AF\u1100-\u11FF]+
# japanese
# tchinese
# schinese
# thai                                        [^\u0E00-\u0E7F]+
# turkish
# english                                          [^A-Za-z' ]+
# french                        [^\u0041-\u005A\u0061-\u007A\]+
# german      [^A-Za-z\u00C4\u00D6\u00DC\u00DF\u00E4\u00F6\u...
# italian     [^\u0041-\u005A\u0061-\u007A\u00C0\u00C1\u00C8...
# czech
# norwegian
# swedish
# polish
# portuguese  [^\u0041-\u005A\u0061-\u007A\u00C0-\u00C3\\u00...
# spanish     [^\u0041-\u005A\u0061-\u007A\u00C1\u00C9\u00CD...
# russian

# %%
import nltk
from nltk.tokenize import TreebankWordTokenizer # 유니코드 대체 대신 토큰화->품사태깅 방식 차용
from nltk.stem import WordNetLemmatizer
# from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
nltk.download("stopwords")
from nltk.tag import pos_tag

tokenizer = TreebankWordTokenizer()
lemmatizer = WordNetLemmatizer()
# stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sasha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
lang = "portuguese"
review_data = pd.read_csv(f"dataset/reviews/{lang}.csv", encoding="utf-8-sig")

display(review_data)
# Out:
#          app_id                  app_name  recommendationid    language  \
# 0        292030  The Witcher 3: Wild Hunt          85177505  portuguese
# 1        292030  The Witcher 3: Wild Hunt          85176839  portuguese
# 2        292030  The Witcher 3: Wild Hunt          85176249  portuguese
# 3        292030  The Witcher 3: Wild Hunt          85173023  portuguese
# 4        292030  The Witcher 3: Wild Hunt          85172417  portuguese
# ...         ...                       ...               ...         ...
# 1385673   99910            Puzzle Pirates           9054695  portuguese
# 1385674   99910            Puzzle Pirates           8792121  portuguese
# 1385675   99910            Puzzle Pirates           8284451  portuguese
# 1385676   99910            Puzzle Pirates           7503357  portuguese
# 1385677   99910            Puzzle Pirates           4456005  portuguese
#
#                                                     review  voted_up  \
# 0        Se um dia alguém falar que esse jogo é ruim na...      True
# 1                                              bom demais       True
# 2                                            Obra prima!!!      True
# 3                                           Jogão da porra      True
# 4                                                very foda      True
# ...                                                    ...       ...
# 1385673                                           viciante      True
# 1385674  Um jogo mto bom !! onde vc compra navios , cas...      True
# 1385675                         Por ser gratuito, compensa      True
# 1385676       Têm uns mini-games bem maneirinhos e tal ___      True
# 1385677  Joguei pela primeira vez na época do Miniclip,...      True
#
#          timestamp_created  quadrant
# 0               1611368498         1
# 1               1611367482         1
# 2               1611366524         1
# 3               1611361229         1
# 4               1611360271         1
# ...                    ...       ...
# 1385673         1392133310         2
# 1385674         1390275470         2
# 1385675         1388024120         2
# 1385676         1382968041         2
# 1385677         1315076992         2
#
# [1385678 rows x 8 columns]

# %%
print(f"[{lang}] - before")
display(review_data)

# 리뷰 데이터 자연어처리
def nlp_review(review):    
    # 텍스트 형태의 데이터가 float으로 불러와지는 경우를 방지하기 위해 명시적으로 형변환
    review = str(review)
    
    # 문자 추출
    pattern = lang_data.unicode_pattern[lang]
    #review = re.sub(pattern, "", review)
    trash = re.compile(r"[\u0021-\u0039]")
    review = trash.sub("", review)

    stop_pt = set(stopwords.words("portuguese"))
    stop_eng = set(stopwords.words("english"))
    
    # 소문자 전환
    review = review.lower()

    # 문장 토큰화
    token_list = tokenizer.tokenize(review)
    tokens = []
    for token in token_list:
        token = "".join(re.findall(pattern, token))
        #print(token)
        tokens.append(token)
    #병합 부분
    lemma_list = []

    for x in tokens:
        if x not in stop_pt and x not in stop_eng:
            lemma_list.append(x)
        
    #result = [lm.lemmatize(w, pos="v") for w in result]

    
    
    #print(tagged_list)

    # 표제어 추출(lemmatization)
    lemma_list = [lemmatizer.lemmatize(x) for x in token_list]
    tagged_list = pos_tag(lemma_list)
    
    # 어간 추출(stemming)
    # nltk의 어간 추출은 단어 원형이 깨지는 경우가 있고, 많은 리뷰에서 일일히 스태머끼리 비교를 할 수 없기에 제외
    
    # 품사 태깅, https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
    pos_list = nltk.pos_tag(lemma_list)
    
    """ 어느 품사까지 포함시킬 것인지?(["VB", "VBD", "VBG", "VBN" ....]) 품사를 지원하지 않는 언어는 무엇이 있는지? """
    # 명사 추출, 표제어 추출 과정을 통해 복수형은 변환되었을 것으로 추정하지만 네개의 품사를 일단 사용
    nouns_list = [x[0] for x in tagged_list if x[1] in ["NN", "NNS", "NNP", "NNPS"]]
     
    if nouns_list:
        return " ".join(nouns_list)
    else:
        # 필터링 결과가 공백인 경우 명시적으로 결측치 처리
        return np.nan


review_data["review"] = review_data[["review"]].apply(
    lambda x: nlp_review(x["review"]), axis=1
)

# 필터링 결과가 결측치인 행 제거
review_data = review_data.dropna(axis=0, how="any")

print(f"[{lang}] - after")
display(review_data)
# Out:
# [portuguese] - before
#          app_id                  app_name  recommendationid    language  \
# 0        292030  The Witcher 3: Wild Hunt          85177505  portuguese
# 1        292030  The Witcher 3: Wild Hunt          85176839  portuguese
# 2        292030  The Witcher 3: Wild Hunt          85176249  portuguese
# 3        292030  The Witcher 3: Wild Hunt          85173023  portuguese
# 4        292030  The Witcher 3: Wild Hunt          85172417  portuguese
# ...         ...                       ...               ...         ...
# 1385673   99910            Puzzle Pirates           9054695  portuguese
# 1385674   99910            Puzzle Pirates           8792121  portuguese
# 1385675   99910            Puzzle Pirates           8284451  portuguese
# 1385676   99910            Puzzle Pirates           7503357  portuguese
# 1385677   99910            Puzzle Pirates           4456005  portuguese
#
#                                                     review  voted_up  \
# 0        Se um dia alguém falar que esse jogo é ruim na...      True
# 1                                              bom demais       True
# 2                                            Obra prima!!!      True
# 3                                           Jogão da porra      True
# 4                                                very foda      True
# ...                                                    ...       ...
# 1385673                                           viciante      True
# 1385674  Um jogo mto bom !! onde vc compra navios , cas...      True
# 1385675                         Por ser gratuito, compensa      True
# 1385676       Têm uns mini-games bem maneirinhos e tal ___      True
# 1385677  Joguei pela primeira vez na época do Miniclip,...      True
#
#          timestamp_created  quadrant
# 0               1611368498         1
# 1               1611367482         1
# 2               1611366524         1
# 3               1611361229         1
# 4               1611360271         1
# ...                    ...       ...
# 1385673         1392133310         2
# 1385674         1390275470         2
# 1385675         1388024120         2
# 1385676         1382968041         2
# 1385677         1315076992         2
#
# [1385678 rows x 8 columns]
# [portuguese] - after
#          app_id                  app_name  recommendationid    language  \
# 0        292030  The Witcher 3: Wild Hunt          85177505  portuguese
# 1        292030  The Witcher 3: Wild Hunt          85176839  portuguese
# 2        292030  The Witcher 3: Wild Hunt          85176249  portuguese
# 3        292030  The Witcher 3: Wild Hunt          85173023  portuguese
# 5        292030  The Witcher 3: Wild Hunt          85169737  portuguese
# ...         ...                       ...               ...         ...
# 1385673   99910            Puzzle Pirates           9054695  portuguese
# 1385674   99910            Puzzle Pirates           8792121  portuguese
# 1385675   99910            Puzzle Pirates           8284451  portuguese
# 1385676   99910            Puzzle Pirates           7503357  portuguese
# 1385677   99910            Puzzle Pirates           4456005  portuguese
#
#                                                     review  voted_up  \
# 0        se dia alguém que esse jogo é ruim juro que ba...      True
# 1                                               bom demais      True
# 2                                               obra prima      True
# 3                                           jogão da porra      True
# 5                                                      bom      True
# ...                                                    ...       ...
# 1385673                                           viciante      True
# 1385674  jogo mto bom onde vc compra navios invadi ilha...      True
# 1385675                          por ser gratuito compensa      True
# 1385676                                têm minigames e ___      True
# 1385677  joguei pela primeira vez grande jogo talvez o ...      True
#
#          timestamp_created  quadrant
# 0               1611368498         1
# 1               1611367482         1
# 2               1611366524         1
# 3               1611361229         1
# 5               1611356281         1
# ...                    ...       ...
# 1385673         1392133310         2
# 1385674         1390275470         2
# 1385675         1388024120         2
# 1385676         1382968041         2
# 1385677         1315076992         2
#
# [1347932 rows x 8 columns]

# %%
pt_text = " ".join(review_data["review"].tolist())
pt_text_counter = Counter(pt_text.split(" "))

display(pt_text_counter.most_common(20))
# Out:
# [('jogo', 1077821),
#  ('e', 775963),
#  ('o', 752980),
#  ('que', 740722),
#  ('é', 622319),
#  ('muito', 510274),
#  ('com', 397472),
#  ('bom', 371824),
#  ('para', 297105),
#  ('da', 235938),
#  ('mais', 220668),
#  ('tem', 205995),
#  ('ma', 204261),
#  ('em', 197225),
#  ('pra', 196453),
#  ('game', 182081),
#  ('você', 181501),
#  ('jogar', 176774),
#  ('se', 162898),
#  ('bem', 151332)]

# %%
#game = jpgp
stopword_list = [":", "?", "[","]","e", "o", "que", "é", "para","com","mais","cada","tudo","foi","te","fazer","até","você","se","bem","sem","quem","vai","ou","já","só","ter","são","tem","isso","ainda","ser","se" "da","ma", "em", "pra","eu","por","esse","jogo","jogar","game"]
for stopword in stopword_list:
    if stopword in pt_text_counter.keys():
        del pt_text_counter[stopword]
        
display(pt_text_counter.most_common(20))
# Out:
# [('muito', 510274),
#  ('bom', 371824),
#  ('melhor', 133706),
#  ('recomendo', 117874),
#  ('como', 117807),
#  ('história', 102013),
#  ('divertido', 82531),
#  ('não', 74836),
#  ('mesmo', 74258),
#  ('boa', 73828),
#  ('tempo', 73268),
#  ('pode', 68999),
#  ('jogabilidade', 63292),
#  ('pena', 63212),
#  ('amigo', 62814),
#  ('joguei', 60172),
#  ('vale', 56247),
#  ('melhores', 52225),
#  ('ótimo', 49771),
#  ('jogos', 48569)]

# %%
mask = np.array(Image.open(f"ref/portugal.png"))

wc = WordCloud(font_path=lang_data.font_path.portuguese, prefer_horizontal=1.0,
               background_color="rgb(255,255,255)", mask=mask, color_func=ImageColorGenerator(mask),
               min_font_size = 10,
               max_words=200, width=2560, height=1707).generate_from_frequencies(pt_text_counter) 

plt.figure(figsize=(20,20))

plt.imshow(wc, interpolation="bicubic")
plt.axis("off")
plt.show()
